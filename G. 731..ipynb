# %% [markdown]
# ### Mech. rezgéseket befolyásoló külső tényezők
#
# - A valóságban a rugóra függesztett test rezgése egy idő után megáll. Csillapodó rezgőmozgásról beszélünk akkor, ha a visszatérítő harmonikus erőn kívül más erő is hat a rezgést végző testre.
# - Például:
#     - közegellenállás
#     - súrlódás
#
# ### Interferencia
#
# - Az interferencia, akkor következik be, ha két különböző forrású hullám, amelyek fáziskülönbsége állandó. Ekkor létrejönnek olyan pontok a térben, ahol a hullámok maximálisan erősítik, illetve olyanok, ahol maximálisan gyengítik egymást (annak függvényében, hogy az egyes pontokba a két hullám milyen fáziskülönbséggel érkezik).
#
# ### Huygens-elv
#
# - A hullámtér minden pontja elemi hullámok kiindulópontja.
# - A hullámtér minden jelensége leírható az elemi hullámok interferenciájaként.
# - A látható hullámfrontot egy adott pillanatban ezen elemi hullámok közös érintője vagy közös burkolója adja.
#
# ### Hullámtörés
#
# - Hullámtörés akkor következik be, amikor hullámtani szempontból különböző közegek határára ferdén érkező hullám terjedési iránya az új közegben megváltozik.
# - Két közeg hullámtani szempontból különböző, ha bennük ugyanannak a hullámnak különböző a terjedési sebessége.
# - Hullámtörési törvény
#     - A beeső sugár, a beesési merőleges és a megtört sugár egy síkban vannak
#     - A beesési szög (a beeső sugár és a beesési merőleges szöge, α) szinuszának és a törési szög (a megtört sugár és a beesési merőleges szöge, β) szinuszának hányadosa egyenlő a törésmutatóval
#     - $ \dfrac{\sin \alpha}{\sin \beta} = \dfrac{c_1}{c_2} = n_{1,2} $
#
# ### Doppler-hatás
#
# - A hullám frekvenciájában és ezzel együtt hullámhosszában megjelenő változás, mely amiatt alakul ki, hogy a hullámforrás és a megfigyelő egymáshoz képest mozog.
# - Ha a mozgó forrás f0 frekvenciájú hullámot bocsát ki, akkor a közeghez képest álló megfigyelő az alábbi módon meghatározható f frekvenciát észlel:
#     - $ f = f_0 \cdot \dfrac{c}{c-v} $
#     - a forrás mozgása nem változtatja meg a mért hullámsebességet, de a hullámhosszat igen
# - Mozgó megfigyelőre és álló forrásra a következőt kapjuk (a megfigyelő sebessége a v):
#     - $ f = f_0 \cdot \dfrac{c+v}{c} = f_0\left(1+\dfrac{v}{c}\right) $
#     - a mért hullámhossz nem függ a megfigyelő sebességétől, de a hullámsebesség igen

# %% [markdown]
# ### G. 731.
#
# Egy kertvárosi övezetben, ahol 30 km/h a megengedett legnagyobb sebesség, egy autó – kicsit szabálytalanul – 36 km/h sebességgel halad. Megelőzi őt egy másik, ugyanolyan autó 54 km/h sebességgel. Éppen egymás mellett haladnak, amikor 20 méternyire előttük egy gyerek kiszalad az úttestre. A két autó sofőrje egyszerre kezd el ugyanolyan erősen fékezni.
#
# $ \displaystyle a) $ Mekkora ,,megmaradó'' sebességgel halad el a gyerek mellett a gyorsabb autó, ha a lassabb autó éppen megáll a gyerek előtt?
#
# $ \displaystyle b) $ Hogyan változik az eredmény, ha figyelembe vesszük azt is, hogy mindkét sofőr reakcióideje kb. 1 másodperc?

# %% [markdown]
# $ d = 20\,m = s_1 $ (távolság a gyerektől)
# $ v_1 = 36\,\frac{km}{h} = 10\,\frac{m}{s} $
# $ v_2 = 54\,\frac{km}{h} = 15\,\frac{m}{s} $
#
# -----
#
# $ s = \dfrac{a}{2} \cdot t^2 $
#
# $ a = \dfrac{2s}{t^2} = \dfrac{2s}{\dfrac{\Delta v^2}{a^2}} = \dfrac{2s\cdot a^2}{\Delta v^2} = \dfrac{\Delta v^2}{2s} $
#
# $ a = \dfrac{\left(10\,\frac{m}{s}\right)^2}{2\cdot 20\,m} = 2.5\,\frac{m}{s^2} $
#
# <!-- $ t_1 = \dfrac{\Delta v_1}{a} = \dfrac{10\,\frac{m}{s}}{2.5\,\frac{m}{s^2}} = 4\,s  $ -->
#
# $ s_2 = \dfrac{\Delta v_2^2}{2a} = \dfrac{\left(15\,\frac{m}{s}\right)^2}{2 \cdot 2.5\,\frac{m}{s^2} } = 45\,m $
#
# $ t_m = \sqrt{\dfrac{2\left(s_2-d\right)}{a}} = \sqrt{\dfrac{2\left(45\,m - 20\,m\right)}{2.5\,\frac{m}{s^2}}} = 2\sqrt5\,s $ alatt áll meg a gyerek utáni szakaszon
#
# $ \Delta v_m = a \cdot t_m = 2.5\,\frac{m}{s^2} \cdot 2\sqrt5\,s = 5\sqrt5\,\frac{m}{s} $
#
# $ \displaystyle a) $ $ 5\sqrt5\,\frac{m}{s} $ lesz a "megmaradó" sebessége a második járműnek.
#
# -----
#
# $ t_r = 1\,s $
#
# ----
#
# $ s_3 = d - v_1 \cdot t_r = 20\,m - 10\,\frac{m}{s} \cdot 1\,s = 10\,m $ alatt áll meg az első autó
#
# $ t^2 = \dfrac{2s}{a} = \dfrac{2s}{\dfrac{v}{t}} $
#
# $ t = \dfrac{2s}{v} $
#
# $ t_3 = \dfrac{2 \cdot 10\,m}{10\,\frac{m}{s}} = 2\,s $ alatt áll meg az első autó
#
# $ a_2 = \dfrac{v_1}{t_3} = \dfrac{10\,\frac{m}{s}}{2\,s} = 5\,\frac{m}{s^2} $
#
# $ d_2 = d - v_2 \cdot t_r = 20\,m - 15\,\frac{m}{s} \cdot 1\,s = 5\,m $ lesz a második autó távolsága a gyerektől a fékezés megkezdésekor
#
# $ t_4 = \dfrac{v_2}{a_2} = \dfrac{15\,\frac{m}{s}}{5\,\frac{m}{s^2}} = 3\,s $ alatt áll meg a második autó
#
# $ s_4 = \dfrac{a_2}{2} \cdot t_4^2 = \dfrac{5\,\frac{m}{s^2}}{2} \cdot \left(3\,s\right)^2 = 22.5\,m $ alatt áll meg a második autó
#
# $ t_{m2} = \sqrt{\dfrac{2\left(s_4-d_2\right)}{a_2}} = \sqrt{\dfrac{2\left(22.5\,m - 5\,m\right)}{5\,\frac{m}{s^2}}} = \sqrt7\,s $
#
# $ v_{m2} = a_2 \cdot t_m = 5\,\frac{m}{s^2} \cdot \sqrt7\,s = 5\sqrt7\,\frac{m}{s} $
#
# $ \displaystyle b) $ $ 5\sqrt7\,\frac{m}{s} $ lesz a "megmaradó" sebessége a második járműnek a reakcióidőt beszámítva.
